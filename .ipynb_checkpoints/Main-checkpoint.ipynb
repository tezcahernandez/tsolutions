# %% [markdown]
# # Summary data

# %%
# %matplotlib notebook

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
percentGrowthHDI = pd.read_csv("./Datasets/percentGrowthHDI.csv", index_col = 0)
print(percentGrowthHDI.shape)
percentGrowthHDI.rename(columns={
    'Region':'State',
    '2017': "HDI 2017",
    'last year growth': "% HDI growth"
},
                        inplace=True)

percentGrowthHDI["State"][9] = "Ciudad de Mexico"
percentGrowthHDI["State"][7] = "Coahuila de Zaragoza"
percentGrowthHDI["State"][15] = "Mexico."
percentGrowthHDI["State"][30] = "Veracruz de Ignacio de la Llave"
percentGrowthHDI.head()
# Out:
# (32, 3)
# C:\Users\usuario\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # Remove the CWD from sys.path while we load stuff.
# C:\Users\usuario\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # This is added back by InteractiveShellApp.init_path()
# C:\Users\usuario\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if sys.path[0] == '':
# C:\Users\usuario\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   del sys.path[0]
#                  State  HDI 2017  % HDI growth
# 1       Aguascalientes     0.794      0.252525
# 2      Baja California     0.803      0.249688
# 3  Baja California Sur     0.811      0.247219
# 4             Campeche     0.762      0.131406
# 5              Chiapas     0.700      0.286533

# %%
BancosVf = pd.read_csv("./Datasets/BancosVf.csv", index_col = 0)
print(BancosVf.shape)
BancosVf["State"][6] = "Ciudad de Mexico"
BancosVf["State"][7] = "Coahuila de Zaragoza"
BancosVf["State"][14] = "Mexico."
BancosVf["State"][29] = "Veracruz de Ignacio de la Llave"

cols = BancosVf.select_dtypes(include=[np.object]).columns
BancosVf[cols] = BancosVf[cols].apply(lambda x: x.str.normalize('NFKD').str.encode('ascii', errors='ignore').str.decode('utf-8'))
# Out:
# (32, 9)
# C:\Users\usuario\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\usuario\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# C:\Users\usuario\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# C:\Users\usuario\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
BancosVf.head()
# Out:
#                  State  Crec. ATMs  Crec. Transacciones por Celular  \
# 0       Aguascalientes    8.193980                        66.639509
# 1      Baja California    9.808853                        51.534102
# 2  Baja California Sur    8.052434                        47.812462
# 3             Campeche    3.296703                        46.072058
# 4              Chiapas    7.411908                        43.585872
#
#    Crec. Tarjetas de Credito  Crec. Surcursales  Cant. ATMs  \
# 0                  -3.588463           3.906250         647
# 1                  -4.822147           0.529101        2183
# 2                  -3.498855           0.869565         577
# 3                  -4.086440          -4.000000         376
# 4                 -12.307624           1.581028         884
#
#    Cant.Transacciones por Celular  Cant. Tarjetas de Credito  \
# 0                          257708                     276919
# 1                          927813                     770479
# 2                          218387                     187963
# 3                          199067                     137635
# 4                          614358                     374585
#
#    Cant. Surcursales
# 0                133
# 1                380
# 2                116
# 3                 96
# 4                257

# %%
educationStatsPerState = pd.read_csv("./Datasets/TopEducationPerState.csv", index_col = 0)
print(educationStatsPerState.shape)
educationStatsPerState['Entidad federativa'] = [row[3:] for row in educationStatsPerState['Entidad federativa']]

educationStatsPerState.rename(columns={
    'Entidad federativa':'State',
    'Educación media superior2': "HighSchool %",
    'Educación superior3': "College and higher %",
    "Grado promedio de escolaridad": "AvgLvlSchooling"
},
                        inplace=True)

cols = educationStatsPerState.select_dtypes(include=[np.object]).columns
educationStatsPerState[cols] = educationStatsPerState[cols].apply(lambda x: x.str.normalize('NFKD').str.encode('ascii', errors='ignore').str.decode('utf-8'))
educationStatsPerState["State"][14] = "Mexico."

educationStatsPerState.head()
# Out:
# (32, 4)
# C:\Users\usuario\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
#                   State  HighSchool %  College and higher %  AvgLvlSchooling
# 0        Aguascalientes     21.845141             20.670093         9.725975
# 1       Baja California     25.462602             19.384175         9.757418
# 2   Baja California Sur     27.366328             21.051714         9.905535
# 3              Campeche     20.279518             20.309485         9.138454
# 4  Coahuila de Zaragoza     21.443746             21.505499         9.897388

# %%
internetPenetration = pd.read_csv("./Datasets/Internet penetration.csv")
internetPenetration.rename(columns={
    'ENTIDAD':'State',
    'P_BAF_E': "% penetretation"
},
                        inplace=True)
internetPenetration = internetPenetration.loc[:,['State', '% penetretation']]

print(internetPenetration.shape)
internetPenetration.head()
# Out:
# (32, 2)
#                   State  % penetretation
# 0        Aguascalientes               54
# 1       Baja California               75
# 2   Baja California Sur               65
# 3              Campeche               25
# 4  Coahuila de Zaragoza               45

# %%
mainDataframe = internetPenetration.merge(percentGrowthHDI, on='State')
mainDataframe = mainDataframe.merge(BancosVf, on='State')
mainDataframe = mainDataframe.merge(educationStatsPerState, on='State')

mainDataframe["y"] = 0
mainDataframe["y"][8] = 1
mainDataframe["y"][13] = 1
# mainDataframe["y"][14] = 1
mainDataframe["y"][18] = 1

print(mainDataframe.shape)
mainDataframe.to_csv("./Datasets/summaryData.csv")

mainDataframe
# Out:
# (32, 16)
# C:\Users\usuario\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\usuario\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
# C:\Users\usuario\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
#                               State  % penetretation  HDI 2017  % HDI growth  \
# 0                    Aguascalientes               54     0.794      0.252525
# 1                   Baja California               75     0.803      0.249688
# 2               Baja California Sur               65     0.811      0.247219
# 3                          Campeche               25     0.762      0.131406
# 4              Coahuila de Zaragoza               45     0.799      0.250941
# 5                            Colima               60     0.783      0.256082
# 6                           Chiapas               18     0.700      0.286533
# 7                         Chihuahua               54     0.793      0.252845
# 8                  Ciudad de Mexico               97     0.830      0.241546
# 9                           Durango               39     0.775      0.258732
# 10                       Guanajuato               50     0.757      0.132275
# 11                         Guerrero               31     0.717      0.279720
# 12                          Hidalgo               30     0.761      0.263505
# 13                          Jalisco               67     0.788      0.254453
# 14                          Mexico.               52     0.782      0.256410
# 15              Michoacan de Ocampo               41     0.745      0.269179
# 16                          Morelos               61     0.775      0.258732
# 17                          Nayarit               44     0.785      0.255428
# 18                       Nuevo Leon               80     0.808      0.248139
# 19                           Oaxaca               24     0.710      0.282486
# 20                           Puebla               43     0.742      0.270270
# 21                        Queretaro               78     0.790      0.253807
# 22                     Quintana Roo               59     0.781      0.256739
# 23                  San Luis Potosi               40     0.757      0.264901
# 24                          Sinaloa               53     0.804      0.124533
# 25                           Sonora               61     0.806      0.248756
# 26                          Tabasco               24     0.773      0.389610
# 27                       Tamaulipas               42     0.792      0.253165
# 28                         Tlaxcala               36     0.770      0.260417
# 29  Veracruz de Ignacio de la Llave               37     0.744      0.269542
# 30                          Yucatan               45     0.773      0.259403
# 31                        Zacatecas               37     0.760      0.263852
#
#     Crec. ATMs  Crec. Transacciones por Celular  Crec. Tarjetas de Credito  \
# 0     8.193980                        66.639509                  -3.588463
# 1     9.808853                        51.534102                  -4.822147
# 2     8.052434                        47.812462                  -3.498855
# 3     3.296703                        46.072058                  -4.086440
# 4     5.063291                        53.476522                  -2.328279
# 5     4.956268                        62.238774                  -7.928304
# 6     7.411908                        43.585872                 -12.307624
# 7     8.880517                        60.915181                   1.792164
# 8     7.016861                        79.570476                   0.946098
# 9     5.802048                        43.382341                  -7.071453
# 10    7.594937                        66.949312                  -4.522679
# 11    7.197943                        51.468784                  -3.712428
# 12   11.068211                        53.476046                  -1.303678
# 13    6.167904                        64.501751                   2.630131
# 14    7.633111                        64.074851                   5.750366
# 15    8.732158                        34.346708                  -1.317920
# 16    9.116809                        61.383711                   4.153005
# 17    3.200000                        53.281166                   0.057350
# 18    5.548550                        79.237032                   7.269417
# 19    5.691057                        61.255291                   8.864863
# 20    9.259259                        53.944579                   1.453151
# 21    5.783582                        64.551438                   9.781032
# 22    5.630936                        70.355463                   5.492987
# 23    8.286674                        39.910126                   5.568988
# 24    8.305921                        39.335007                   7.629246
# 25    7.204611                        36.664399                  11.001860
# 26    7.617729                        45.163528                  11.511485
# 27    6.345733                        60.383448                   9.218114
# 28    7.467532                        49.486895                  21.855037
# 29    4.402772                        32.857520                  18.292690
# 30   10.290557                        38.552344                  -5.663976
# 31    7.881773                        45.859057                 -14.359852
#
#     Crec. Surcursales  Cant. ATMs  Cant.Transacciones por Celular  \
# 0            3.906250         647                          257708
# 1            0.529101        2183                          927813
# 2            0.869565         577                          218387
# 3           -4.000000         376                          199067
# 4           -0.576369        1826                          648182
# 5           -1.041667         360                          168154
# 6            1.581028         884                          614358
# 7            0.755668        2023                          810887
# 8           -0.167038        8251                         5143333
# 9            0.757576         620                          345626
# 10           0.511073        2125                          735971
# 11           2.032520         834                          506139
# 12           0.465116         863                          446801
# 13          -0.668577        3718                         1672588
# 14           0.946143        5175                         2047600
# 15           0.956938        1295                          622963
# 16           0.440529         766                          362676
# 17          -0.819672         516                          221151
# 18          -0.343249        4185                         1188605
# 19           0.746269         910                          393937
# 20          -0.583658        1711                         1004376
# 21           0.847458        1134                          423042
# 22           7.729469        1557                          473595
# 23          -0.442478         967                          358051
# 24           1.704545        1317                          719395
# 25          -0.294118        1488                          833605
# 26          -0.462963         777                          508518
# 27           0.746269        1944                          764256
# 28           0.000000         331                          184271
# 29          -1.994302        2561                         1425706
# 30           1.731602         911                          375233
# 31           0.000000         438                          199401
#
#     Cant. Tarjetas de Credito  Cant. Surcursales  HighSchool %  \
# 0                      276919                133     21.845141
# 1                      770479                380     25.462602
# 2                      187963                116     27.366328
# 3                      137635                 96     20.279518
# 4                      575137                345     21.443746
# 5                      175113                 95     21.719290
# 6                      374585                257     16.375695
# 7                      770812                400     21.431446
# 8                     5862909               1793     26.623140
# 9                      242813                133     20.202632
# 10                    1042324                590     18.370150
# 11                     387933                251     19.637355
# 12                     422137                216     20.264160
# 13                    2180489               1040     20.812619
# 14                    3494027               1387     24.986933
# 15                     813765                422     16.969066
# 16                     441239                228     22.793206
# 17                     226808                121     22.184918
# 18                    1637399                871     22.838405
# 19                     409321                270     16.095182
# 20                     973584                511     18.993324
# 21                     551743                238     20.876130
# 22                     393127                223     25.785257
# 23                     452797                225     19.707049
# 24                     799272                358     23.918352
# 25                     691122                339     24.761251
# 26                     376804                215     23.495783
# 27                     790145                405     23.136665
# 28                     200666                 87     22.259574
# 29                    1567707                688     19.664855
# 30                     413971                235     19.908730
# 31                     180699                124     16.423473
#
#     College and higher %  AvgLvlSchooling  y
# 0              20.670093         9.725975  0
# 1              19.384175         9.757418  0
# 2              21.051714         9.905535  0
# 3              20.309485         9.138454  0
# 4              21.505499         9.897388  0
# 5              22.029623         9.528720  0
# 6              11.700822         7.288581  0
# 7              18.837425         9.466591  0
# 8              32.137140        11.119587  1
# 9              16.672646         9.147610  0
# 10             13.154603         8.381851  0
# 11             12.887204         7.802707  0
# 12             14.926700         8.715457  0
# 13             18.953275         9.249861  1
# 14             17.854740         9.528067  0
# 15             13.311480         7.926167  0
# 16             18.145495         9.303001  0
# 17             18.660551         9.158921  0
# 18             24.172711        10.274956  1
# 19             11.585514         7.515763  0
# 20             16.477725         8.493854  0
# 21             21.153766         9.553260  0
# 22             18.615485         9.615036  0
# 23             16.666881         8.819995  0
# 24             23.035156         9.581325  0
# 25             21.936253        10.001429  0
# 26             18.769078         9.311769  0
# 27             19.366941         9.508512  0
# 28             16.694763         9.274112  0
# 29             15.562787         8.203438  0
# 30             18.163552         8.821077  0
# 31             14.978422         8.629599  0

# %%
# mainDataframe.nlargest(1, "% penetretation")["State"]
# for columnName in mainDataframe.set_index("State").columns.tolist():
#     print(columnName)
#     print(mainDataframe.nlargest(8, columnName)["State"])
#     print("-----------------")
#     print(f"category: {columnName} winner: {str(mainDataframe.nlargest(1, columnName)["State"])}")

# %%
from sklearn import linear_model
import statsmodels.api as sm
df = mainDataframe

# %%
columnsList = df.columns.tolist()
del columnsList[0]
del columnsList[-1]
columnsList
# Out:
# ['% penetretation',
#  'HDI 2017',
#  '% HDI growth',
#  'Crec. ATMs',
#  'Crec. Transacciones por Celular',
#  'Crec. Tarjetas de Credito',
#  'Crec. Surcursales',
#  'Cant. ATMs',
#  'Cant.Transacciones por Celular',
#  'Cant. Tarjetas de Credito',
#  'Cant. Surcursales',
#  'HighSchool %',
#  'College and higher %',
#  'AvgLvlSchooling']

# %%
# X = df[['Cant. Tarjetas de Credito','Crec. Transacciones por Celular']] # here we have 2 variables for multiple regression. If you just want to use one variable for simple linear regression, then use X = df['Interest_Rate'] for example.Alternatively, you may add additional variables within the brackets
X= df[columnsList]
Y = df['y']
 
# with sklearn
regr = linear_model.LinearRegression()
regr.fit(X, Y)

print('Intercept: \n', regr.intercept_)
print('Coefficients: \n', regr.coef_)


# prediction with sklearn
# New_Interest_Rate = 2.75
# New_Unemployment_Rate = 5.3
# print ('Predicted Stock Index Price: \n', regr.predict([[New_Interest_Rate ,New_Unemployment_Rate]]))


# with statsmodels
X = sm.add_constant(X) # adding a constant
 
model = sm.OLS(Y, X).fit()
predictions = model.predict(X) 
 
print_model = model.summary()
print(print_model)
# Out:
# Intercept:
#  -0.762511067738768
# Coefficients:
#  [ 2.46186357e-03  1.61934641e-01  8.39308702e-01 -8.80734867e-03
#   5.07765541e-03 -8.41786866e-04 -6.27929625e-03 -5.66366204e-05
#   2.92598086e-07 -5.35098731e-07  1.45039616e-03 -3.02085814e-02
#   3.66572451e-02 -8.77901814e-03]
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.737
# Model:                            OLS   Adj. R-squared:                  0.520
# Method:                 Least Squares   F-statistic:                     3.397
# Date:                Fri, 05 Apr 2019   Prob (F-statistic):            0.00938
# Time:                        22:28:17   Log-Likelihood:                 15.392
# No. Observations:                  32   AIC:                           -0.7846
# Df Residuals:                      17   BIC:                             21.20
# Df Model:                          14
# Covariance Type:            nonrobust
# ===================================================================================================
#                                       coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------
# const                              -0.7625      2.991     -0.255      0.802      -7.073       5.548
# % penetretation                     0.0025      0.004      0.565      0.580      -0.007       0.012
# HDI 2017                            0.1619      6.347      0.026      0.980     -13.228      13.552
# % HDI growth                        0.8393      0.892      0.941      0.360      -1.042       2.721
# Crec. ATMs                         -0.0088      0.024     -0.371      0.716      -0.059       0.041
# Crec. Transacciones por Celular     0.0051      0.005      0.978      0.342      -0.006       0.016
# Crec. Tarjetas de Credito          -0.0008      0.005     -0.163      0.873      -0.012       0.010
# Crec. Surcursales                  -0.0063      0.027     -0.234      0.817      -0.063       0.050
# Cant. ATMs                      -5.664e-05      0.000     -0.260      0.798      -0.001       0.000
# Cant.Transacciones por Celular   2.926e-07   3.06e-07      0.956      0.353   -3.53e-07    9.38e-07
# Cant. Tarjetas de Credito       -5.351e-07   3.23e-07     -1.656      0.116   -1.22e-06    1.47e-07
# Cant. Surcursales                   0.0015      0.001      1.414      0.176      -0.001       0.004
# HighSchool %                       -0.0302      0.028     -1.084      0.294      -0.089       0.029
# College and higher %                0.0367      0.035      1.034      0.316      -0.038       0.111
# AvgLvlSchooling                    -0.0088      0.334     -0.026      0.979      -0.712       0.695
# ==============================================================================
# Omnibus:                        0.639   Durbin-Watson:                   2.115
# Prob(Omnibus):                  0.726   Jarque-Bera (JB):                0.432
# Skew:                           0.277   Prob(JB):                        0.806
# Kurtosis:                       2.870   Cond. No.                     3.53e+08
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.53e+08. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
mainDataframeT = mainDataframe.set_index("State").T
mainDataframeT
# mainDataframeT["y coef"] = model.params
# Out:
# State                            Aguascalientes  Baja California  \
# % penetretation                       54.000000        75.000000
# HDI 2017                               0.794000         0.803000
# % HDI growth                           0.252525         0.249688
# Crec. ATMs                             8.193980         9.808853
# Crec. Transacciones por Celular       66.639509        51.534102
# Crec. Tarjetas de Credito             -3.588463        -4.822147
# Crec. Surcursales                      3.906250         0.529101
# Cant. ATMs                           647.000000      2183.000000
# Cant.Transacciones por Celular    257708.000000    927813.000000
# Cant. Tarjetas de Credito         276919.000000    770479.000000
# Cant. Surcursales                    133.000000       380.000000
# HighSchool %                          21.845141        25.462602
# College and higher %                  20.670093        19.384175
# AvgLvlSchooling                        9.725975         9.757418
# y                                      0.000000         0.000000
#
# State                            Baja California Sur       Campeche  \
# % penetretation                            65.000000      25.000000
# HDI 2017                                    0.811000       0.762000
# % HDI growth                                0.247219       0.131406
# Crec. ATMs                                  8.052434       3.296703
# Crec. Transacciones por Celular            47.812462      46.072058
# Crec. Tarjetas de Credito                  -3.498855      -4.086440
# Crec. Surcursales                           0.869565      -4.000000
# Cant. ATMs                                577.000000     376.000000
# Cant.Transacciones por Celular         218387.000000  199067.000000
# Cant. Tarjetas de Credito              187963.000000  137635.000000
# Cant. Surcursales                         116.000000      96.000000
# HighSchool %                               27.366328      20.279518
# College and higher %                       21.051714      20.309485
# AvgLvlSchooling                             9.905535       9.138454
# y                                           0.000000       0.000000
#
# State                            Coahuila de Zaragoza         Colima  \
# % penetretation                             45.000000      60.000000
# HDI 2017                                     0.799000       0.783000
# % HDI growth                                 0.250941       0.256082
# Crec. ATMs                                   5.063291       4.956268
# Crec. Transacciones por Celular             53.476522      62.238774
# Crec. Tarjetas de Credito                   -2.328279      -7.928304
# Crec. Surcursales                           -0.576369      -1.041667
# Cant. ATMs                                1826.000000     360.000000
# Cant.Transacciones por Celular          648182.000000  168154.000000
# Cant. Tarjetas de Credito               575137.000000  175113.000000
# Cant. Surcursales                          345.000000      95.000000
# HighSchool %                                21.443746      21.719290
# College and higher %                        21.505499      22.029623
# AvgLvlSchooling                              9.897388       9.528720
# y                                            0.000000       0.000000
#
# State                                  Chiapas      Chihuahua  \
# % penetretation                      18.000000      54.000000
# HDI 2017                              0.700000       0.793000
# % HDI growth                          0.286533       0.252845
# Crec. ATMs                            7.411908       8.880517
# Crec. Transacciones por Celular      43.585872      60.915181
# Crec. Tarjetas de Credito           -12.307624       1.792164
# Crec. Surcursales                     1.581028       0.755668
# Cant. ATMs                          884.000000    2023.000000
# Cant.Transacciones por Celular   614358.000000  810887.000000
# Cant. Tarjetas de Credito        374585.000000  770812.000000
# Cant. Surcursales                   257.000000     400.000000
# HighSchool %                         16.375695      21.431446
# College and higher %                 11.700822      18.837425
# AvgLvlSchooling                       7.288581       9.466591
# y                                     0.000000       0.000000
#
# State                            Ciudad de Mexico        Durango  \
# % penetretation                      9.700000e+01      39.000000
# HDI 2017                             8.300000e-01       0.775000
# % HDI growth                         2.415459e-01       0.258732
# Crec. ATMs                           7.016861e+00       5.802048
# Crec. Transacciones por Celular      7.957048e+01      43.382341
# Crec. Tarjetas de Credito            9.460981e-01      -7.071453
# Crec. Surcursales                   -1.670379e-01       0.757576
# Cant. ATMs                           8.251000e+03     620.000000
# Cant.Transacciones por Celular       5.143333e+06  345626.000000
# Cant. Tarjetas de Credito            5.862909e+06  242813.000000
# Cant. Surcursales                    1.793000e+03     133.000000
# HighSchool %                         2.662314e+01      20.202632
# College and higher %                 3.213714e+01      16.672646
# AvgLvlSchooling                      1.111959e+01       9.147610
# y                                    1.000000e+00       0.000000
#
# State                                ...         Quintana Roo  \
# % penetretation                      ...            59.000000
# HDI 2017                             ...             0.781000
# % HDI growth                         ...             0.256739
# Crec. ATMs                           ...             5.630936
# Crec. Transacciones por Celular      ...            70.355463
# Crec. Tarjetas de Credito            ...             5.492987
# Crec. Surcursales                    ...             7.729469
# Cant. ATMs                           ...          1557.000000
# Cant.Transacciones por Celular       ...        473595.000000
# Cant. Tarjetas de Credito            ...        393127.000000
# Cant. Surcursales                    ...           223.000000
# HighSchool %                         ...            25.785257
# College and higher %                 ...            18.615485
# AvgLvlSchooling                      ...             9.615036
# y                                    ...             0.000000
#
# State                            San Luis Potosi        Sinaloa  \
# % penetretation                        40.000000      53.000000
# HDI 2017                                0.757000       0.804000
# % HDI growth                            0.264901       0.124533
# Crec. ATMs                              8.286674       8.305921
# Crec. Transacciones por Celular        39.910126      39.335007
# Crec. Tarjetas de Credito               5.568988       7.629246
# Crec. Surcursales                      -0.442478       1.704545
# Cant. ATMs                            967.000000    1317.000000
# Cant.Transacciones por Celular     358051.000000  719395.000000
# Cant. Tarjetas de Credito          452797.000000  799272.000000
# Cant. Surcursales                     225.000000     358.000000
# HighSchool %                           19.707049      23.918352
# College and higher %                   16.666881      23.035156
# AvgLvlSchooling                         8.819995       9.581325
# y                                       0.000000       0.000000
#
# State                                   Sonora        Tabasco     Tamaulipas  \
# % penetretation                      61.000000      24.000000      42.000000
# HDI 2017                              0.806000       0.773000       0.792000
# % HDI growth                          0.248756       0.389610       0.253165
# Crec. ATMs                            7.204611       7.617729       6.345733
# Crec. Transacciones por Celular      36.664399      45.163528      60.383448
# Crec. Tarjetas de Credito            11.001860      11.511485       9.218114
# Crec. Surcursales                    -0.294118      -0.462963       0.746269
# Cant. ATMs                         1488.000000     777.000000    1944.000000
# Cant.Transacciones por Celular   833605.000000  508518.000000  764256.000000
# Cant. Tarjetas de Credito        691122.000000  376804.000000  790145.000000
# Cant. Surcursales                   339.000000     215.000000     405.000000
# HighSchool %                         24.761251      23.495783      23.136665
# College and higher %                 21.936253      18.769078      19.366941
# AvgLvlSchooling                      10.001429       9.311769       9.508512
# y                                     0.000000       0.000000       0.000000
#
# State                                 Tlaxcala  \
# % penetretation                      36.000000
# HDI 2017                              0.770000
# % HDI growth                          0.260417
# Crec. ATMs                            7.467532
# Crec. Transacciones por Celular      49.486895
# Crec. Tarjetas de Credito            21.855037
# Crec. Surcursales                     0.000000
# Cant. ATMs                          331.000000
# Cant.Transacciones por Celular   184271.000000
# Cant. Tarjetas de Credito        200666.000000
# Cant. Surcursales                    87.000000
# HighSchool %                         22.259574
# College and higher %                 16.694763
# AvgLvlSchooling                       9.274112
# y                                     0.000000
#
# State                            Veracruz de Ignacio de la Llave  \
# % penetretation                                     3.700000e+01
# HDI 2017                                            7.440000e-01
# % HDI growth                                        2.695418e-01
# Crec. ATMs                                          4.402772e+00
# Crec. Transacciones por Celular                     3.285752e+01
# Crec. Tarjetas de Credito                           1.829269e+01
# Crec. Surcursales                                  -1.994302e+00
# Cant. ATMs                                          2.561000e+03
# Cant.Transacciones por Celular                      1.425706e+06
# Cant. Tarjetas de Credito                           1.567707e+06
# Cant. Surcursales                                   6.880000e+02
# HighSchool %                                        1.966486e+01
# College and higher %                                1.556279e+01
# AvgLvlSchooling                                     8.203438e+00
# y                                                   0.000000e+00
#
# State                                  Yucatan      Zacatecas
# % penetretation                      45.000000      37.000000
# HDI 2017                              0.773000       0.760000
# % HDI growth                          0.259403       0.263852
# Crec. ATMs                           10.290557       7.881773
# Crec. Transacciones por Celular      38.552344      45.859057
# Crec. Tarjetas de Credito            -5.663976     -14.359852
# Crec. Surcursales                     1.731602       0.000000
# Cant. ATMs                          911.000000     438.000000
# Cant.Transacciones por Celular   375233.000000  199401.000000
# Cant. Tarjetas de Credito        413971.000000  180699.000000
# Cant. Surcursales                   235.000000     124.000000
# HighSchool %                         19.908730      16.423473
# College and higher %                 18.163552      14.978422
# AvgLvlSchooling                       8.821077       8.629599
# y                                     0.000000       0.000000
#
# [15 rows x 32 columns]

# %%
(mainDataframeT["Chiapas"][0:-1])
# Out:
# % penetretation                        18.000000
# HDI 2017                                0.700000
# % HDI growth                            0.286533
# Crec. ATMs                              7.411908
# Crec. Transacciones por Celular        43.585872
# Crec. Tarjetas de Credito             -12.307624
# Crec. Surcursales                       1.581028
# Cant. ATMs                            884.000000
# Cant.Transacciones por Celular     614358.000000
# Cant. Tarjetas de Credito          374585.000000
# Cant. Surcursales                     257.000000
# HighSchool %                           16.375695
# College and higher %                   11.700822
# AvgLvlSchooling                         7.288581
# Name: Chiapas, dtype: float64

# %%
model.params[1:]
# Out:
# % penetretation                    1.787822e-04
# HDI 2017                          -3.951618e+00
# % HDI growth                       1.034102e+00
# Crec. ATMs                        -8.757141e-03
# Crec. Transacciones por Celular    1.519448e-03
# Crec. Tarjetas de Credito         -4.975877e-03
# Crec. Surcursales                 -2.015193e-03
# Cant. ATMs                        -2.101707e-05
# Cant.Transacciones por Celular    -4.113867e-07
# Cant. Tarjetas de Credito          8.948007e-08
# Cant. Surcursales                  1.365054e-03
# HighSchool %                      -5.477692e-03
# College and higher %               2.369269e-02
# AvgLvlSchooling                    1.597063e-01
# dtype: float64

# %%
print(model.params.shape)
print(mainDataframeT["Ciudad de Mexico"].shape)
model.params[1:]
mainDataframeT["Ciudad de Mexico"][0:-1]
(model.params[1:] * mainDataframeT["Ciudad de Mexico"][0:-1]).sum()
# Out:
# (15,)
# (15,)
# 1.6955605101122877

# %%
print(model.params.shape)
print(mainDataframeT["Chiapas"].shape)
model.params[1:]
mainDataframeT["Chiapas"][0:-1]
(model.params[1:] * mainDataframeT["Chiapas"][0:-1]).sum()
# Out:
# (15,)
# (15,)
# 0.7268766976740919

# %%
statesResult = {}
for column in mainDataframeT:
    statesResult[column] = [(model.params[1:] * mainDataframeT[column][0:-1]).sum()]
#     print(column)
#     print((model.params[1:] * mainDataframeT[column][0:-1]).sum())
#     print("--------------------------------")

pd.DataFrame(statesResult).T
# Out:
#                                         0
# Aguascalientes                   0.814059
# Baja California                  0.842685
# Baja California Sur              0.625109
# Campeche                         0.682880
# Coahuila de Zaragoza             1.015835
# Colima                           0.915710
# Chiapas                          0.726877
# Chihuahua                        0.948801
# Ciudad de Mexico                 1.695561
# Durango                          0.658606
# Guanajuato                       0.877019
# Guerrero                         0.683525
# Hidalgo                          0.618241
# Jalisco                          1.386600
# Mexico.                          0.981316
# Michoacan de Ocampo              0.731419
# Morelos                          0.770218
# Nayarit                          0.720362
# Nuevo Leon                       1.489433
# Oaxaca                           0.768718
# Puebla                           1.020521
# Queretaro                        0.966698
# Quintana Roo                     0.724204
# San Luis Potosi                  0.643404
# Sinaloa                          0.739854
# Sonora                           0.854597
# Tabasco                          0.778206
# Tamaulipas                       0.888066
# Tlaxcala                         0.511113
# Veracruz de Ignacio de la Llave  0.898514
# Yucatan                          0.717192
# Zacatecas                        0.705013

# %%
pd.DataFrame(statesResult).T.nlargest(8, 0)
# Out:
#                              0
# Ciudad de Mexico      1.695561
# Nuevo Leon            1.489433
# Jalisco               1.386600
# Puebla                1.020521
# Coahuila de Zaragoza  1.015835
# Mexico.               0.981316
# Queretaro             0.966698
# Chihuahua             0.948801
